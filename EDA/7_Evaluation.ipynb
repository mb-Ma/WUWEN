# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import sys, os
sys.path.append(os.path.abspath(".."))  # 上一级目录

from utils.metrics import Metrics

# %%
result = np.load("../outputs/2025-10-13/16-55-10/result.npz")

# %%
result.files
# Out:
# ['real_y', 'pred_y']

# %%
result['pred_y'].shape
# Out:
# (30338, 12, 2)

# %%
mae, rmse, mape, smape = Metrics(result['pred_y'][..., 1], result['real_y'][..., 1])

# %%
print(mae, rmse)
# Out:
# 3.4815452746804953 6.484401889362531

# %%
result = np.load("../outputs/2025-10-13/17-36-29/result.npz")
mae, rmse, mape, smape = Metrics(result['pred_y'][..., 0], result['real_y'][..., 0])

# %%
print(mae, rmse)
# Out:
# 28.41071323410246 65.73060127600678
